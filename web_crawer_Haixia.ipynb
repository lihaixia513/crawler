# %%
from urllib.request import Request, urlopen #changed from indeed.py
#the reason: https://www.educative.io/edpresso/what-is-the-urllib-module-in-python-3
from selenium import webdriver
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import time
import random
import os
import json

# %%
head = "https://www.walmart.com/"

chromedriver = "C:/Users/h/Desktop/ML/week13_Defining_Keystone_Project/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver

title = ["kids+toys"]

# %%
class Walmart_Webcrawler(object):
    
    def __init__(self, url, job_title, time_str):
        self.url = url
        self.job_title = job_title
        self.time_str = time_str

    def get_soup(self, url):
        """
        This function get the beautifulsoup object of a webpage.

        Args:
            url (str): the link string of webpage

        Returns:
            soup (obj): beautifulsoup object
        """
        request = Request(url, headers={'User-Agent': 'Resistance is futile'})
        response = urlopen(request)
        return BeautifulSoup(response, "html.parser")

    def get_jobs_of_title(self, job_title):
        """
        Args:
            job_title (str): example: 'kids+toys'

        Returns:
        """

        #needed to be changed
        num_pages = 1 #number of pages to scrape
        page_gap_min = 3 #min sleep time between pages
        page_gap_max = 5 #max sleep time between pages
        job_per_page = 50 #number of jobs in one page
        job_gap_min = 5 #min sleep time between jobs
        job_gap_max = 6 #max sleep time between jobs

        for i in range(num_pages): 
            #sleep between each call
            gap = random.uniform(page_gap_min,page_gap_max) 
            time.sleep(gap)

            #each page contains 50 jobs
            tail = "search?q={0}&sort=date&limit={1}".format(job_title,job_per_page)
#             if i>0:
#                 tail += "&start={0}".format(i*job_per_page)

            #get link to joblist page
            url = head+tail 

            #get links to webpages of jobs on the joblist
            job_page_links = self.get_job_links_from_page(url)

            for job_page_link in job_page_links:
                gap = random.uniform(job_gap_min,job_gap_max) 
                time.sleep(gap)
                data = self.get_info_from_job_page(job_page_link)

                print(json.dumps(data))

    def get_job_links_from_page(self, url):
        """
        This function gets the links of the jobs on the joblist page.

        Args:
            url (str): link to joblist page

        Returns:
            job_page_links (list): list of links to the webpages of the jobs
        """

        job_page_links = []
        soup = self.get_soup(url)
        for item in soup.find_all("a", href=True):
            if '/rc/clk?jk=' in str(item) and 'fccid=' in str(item):
                link = item['href'].split("clk?")[1]
                job_page_links.append(head+'viewjob?'+link)
        return job_page_links

    def get_info_from_job_page(self, url):
        """
        This function get all the useful info from the job webpage.

        Args:
            url (str): link to job webpage

        Returns:
            data (dict): dictionary with keywords: 
                         time_stamp, original_link, job_title, location, company, description
        """
        soup = self.get_soup(url)
        data = {}
        time_str = soup.find('div',class_='result-link-bar').find('span').getText()

        try:
            data["time_stamp"] = self.get_timestamp(time_str).strftime("%d-%m-%Y %H:%M")
#             data["job_title"] = soup.find('b', class_='jobtitle').getText()
#             data["location"] = soup.find('span', class_='location').getText()
#             data["company"] = soup.find('span', class_='company').getText()
#             data["description"] = soup.find('td',class_='snip').find('div').getText()
            data["name"] = soup.find('h', class_='name').getText()
            data["price"] = soup.find('span', class_='price').getText()
        
            re_link = soup.find('a',class_='ratingCount')['href'].split("&from=")[0]
            re_link = head[:-1]+re_link
            data["original_link"] = self.get_original_link(re_link)
        except:
            pass
        return data

    def get_timestamp(self, time_str):
        """
        Calculate the timestamp from the time string.

        Args:
            time_str (str): time string, like '2 hours ago'

        Returns:
            time_stamp (obj): timestamp object
        """
        if 'hour' in time_str:
            lag = int(time_str.split('hour')[0])
            delta = timedelta(hours=lag)
            now = datetime.utcnow().replace(second=0,minute=0)
            return now-delta
        else:
            return -1

    def get_original_link(self, url):
        """
        Get the original link of the job description.

        Args:
            url (str): the link in Indeed database

        Returns:
            url (str): the original link to the job description
        """
        driver = webdriver.Chrome(chromedriver)
        driver.get(url)
        time.sleep(2)
        original_url = driver.current_url
        driver.quit()
        return original_url

#do not need the following codes in notebook, but it is required in .py file
#     if __name__ == "__main__":     
#         get_jobs_of_title("data+scientist")

# %%
Walmart_Webcrawler(head, job_title, "2 hours ago")

# %%
crawler

# %% [markdown]
# ### run the functions seperately

# %%
head = "https://www.walmart.com/"

chromedriver = "C:/Users/h/Desktop/ML/week13_Defining_Keystone_Project/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver

title = ["kids+toys"]

# %%
def get_soup(url): # function 1-get main page url
        """
        This function get the beautifulsoup object of a webpage.

        Args:
            url (str): the link string of webpage

        Returns:
            soup (obj): beautifulsoup object
        """
        request = Request(url, headers={'User-Agent': 'Resistance is futile'})
        response = urlopen(request)
        return BeautifulSoup(response, "html.parser")

# %%
soup = get_soup(head)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head nonce="zP56o21iWyj1GplF"><link href="//dis.criteo.com" rel="dns-prefetch"/><link href="//ib.adnxs.com" rel="dns-prefetch"/><link href="//secure-assets.rubiconproject.com" rel="dns-prefetch"/><link href="//beam.hlserve.com" rel="dns-prefetch"/><link href="//pubads.g.doubleclick.net" rel="dns-prefetch"/><link href="//omniture-ssl.walmart.com" rel="dns-prefetch"/><link href="//omniture.walmart.com" rel="dns-prefetch"/><link href="//p.typekit.net" rel="dns-prefetch"/><link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/><link href="//partner.googleadservices.com" rel="dns-prefetch"/><link href="//tpc.googlesyndication.com" rel="dns-prefetch"/><link href="//beacon.walmart.com" rel="dns-prefetch"/><link href="//b.wal.co" rel="dns-prefetch"/><link href="//i5.wal.co" rel="dns-prefetch"/><link href="//i5.walmartimages.com" rel="dns-prefetch"/><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><meta content="105223049547814" property="fb:app_id"/><link as="font" crossorigin="anonymous" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Bold.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Regular.woff2" rel="preload" type="font/woff2"/><script defer="" nonce="zP56o21iWyj1GplF" src="https://www.walmart.com/px/PXu6b0qd2S/init.js"></script><script nonce="zP56o21iWyj1GplF">var _bcq = _bcq || [];_bcq.push(['_setOptions', { start_time: (new Date()).getTime(), bd: 'beacon.walmart.com', bh: 'beacon.lightest.walmart.com', sv: '1.0.65' }]);</script><script async="" nonce="zP56o21iWyj1GplF" src="//i5.walmartimages.com/beacon/beacon.js?bd=beacon.walmart.com&amp;bh=beacon.lightest.walmart.com"></script><link as="image" href="//i5.walmartimages.com/dfw/63fd9f59-b3e1/7a569e53-f29a-4c3d-bfaf-6f7a158bfadd/v1/walmartLogo.svg" rel="preload"/><title>Walmart.com | Save Money. Live Better</title><meta content="Shop Walmart.com for Every Day Low Prices. Free Shipping on Orders $35+ or Pickup In-Store and get a Pickup Discount. Open a Walmart Credit Card to Save Even More!" name="description"/><meta content="Walmart,Walmart.com,Online Shopping,Gifts,Toys,Home,Jewelry,TVs,HD TVs,Smart TVs,Electronics,Baby Products,Video Games,Computers,Laptops,Cell Phones,Games,Apparel,Clothing,Fashion,Accessories,Shoes,Watches,Sports &amp; Outdoors, Sporting Goods,Office Products,Health,Vitamins,Personal Care,Beauty Products,Garden,Bed,Bath,Furniture,Tools,Hardware, Vacuums,Outdoor Living,Automotive Parts,Pet Food,Pet Supplies,iphone" name="keywords"/><link href="https://www.walmart.com/" rel="canonical"/><meta content="https://www.walmart.com/" property="og:url"/><meta content="Shop Walmart.com for Every Day Low Prices. Free Shipping on Orders $35+ or Pickup In-Store and get a Pickup Discount. Open a Walmart Credit Card to Save Even More!" property="og:description"/><meta content="Walmart.com | Save Money. Live Better" property="og:title"/><meta content="Website" property="og:type"/><meta content="https://i5.walmartimages.com/dfw/63fd9f59-49ff/k2-_52fee322-2e60-452a-bccc-1e847f452a13.v1.png" property="og:image"/><meta content="Walmart.com" property="og:site_name"/><script nonce="zP56o21iWyj1GplF" type="application/ld+json">{"@context":"https://schema.org","@type":"Organization","name":"Walmart","url":"https://www.walmart.com/","logo":"https://i5.walmartimages.com/dfw/63fd9f59-b3e1/7a569e53-f29a-4c3d-bfaf-6f7a158bfadd/v1/walmartLogo.svg"}</script><link as="image" href="https://i5.walmartimages.com/dfw/4ff9c6c9-60ed/k2-_29505931-7c67-4589-94a8-13b35880e635.v1.jpg" rel="preload"/><link as="image" href="https://i5.walmartimages.com/dfw/4ff9c6c9-ea8b/k2-_7ab39bd2-58b0-4439-877f-3f50fff6f7c1.v1.jpg" rel="preload"/><link as="image" href="https://i5.walmartimages.com/dfw/4ff9c6c9-ca75/k2-_a5e36ecc-f0af-4286-a8b7-91a752c2715a.v1.jpg"  ...
#           https://i5.walmartimages.com/dfw/4ff9c6c9-64d0/k2-_f0d316e7-25a9-4436-a60d-2efd62702aa3.v1.png?odnHeight=180&amp;odnWidth=180&amp;odnBg=FFFFFF 2x" width="90"/><p class="tc f6 dark-gray ma0 mv2">Pharmacy</p></a></div><div class="dib w-33"><a class="no-underline flex flex-column items-center ph2" href="/cp/auto-services/1087266?gbo=1" link-identifier="Auto Care Center"><img alt="" class="h-100" height="90" loading="lazy" src="https://i5.walmartimages.com/dfw/4ff9c6c9-15ce/k2-_ad628e1a-53e3-4f61-9359-a2660f4792af.v1.png" srcset="https://i5.walmartimages.com/dfw/4ff9c6c9-15ce/k2-_ad628e1a-53e3-4f61-9359-a2660f4792af.v1.png?odnHeight=90&amp;odnWidth=90&amp;odnBg=FFFFFF 1x,
#           https://i5.walmartimages.com/dfw/4ff9c6c9-15ce/k2-_ad628e1a-53e3-4f61-9359-a2660f4792af.v1.png?odnHeight=180&amp;odnWidth=180&amp;odnBg=FFFFFF 2x" width="90"/><p class="tc f6 dark-gray ma0 mv2">Auto Care Center</p></a></div><div class="dib w-33"><a class="no-underline flex flex-column items-center ph2" href="https://www.walmart.com/order-ahead/cake" link-identifier="Custom Cakes"><img alt="" class="h-100" height="90" loading="lazy" src="https://i5.walmartimages.com/dfw/4ff9c6c9-7115/k2-_72d8477e-8b41-404f-b891-c6ee5b6e68ff.v1.png" srcset="https://i5.walmartimages.com/dfw/4ff9c6c9-7115/k2-_72d8477e-8b41-404f-b891-c6ee5b6e68ff.v1.png?odnHeight=90&amp;odnWidth=90&amp;odnBg=FFFFFF 1x,
#           https://i5.walmartimages.com/dfw/4ff9c6c9-7115/k2-_72d8477e-8b41-404f-b891-c6ee5b6e68ff.v1.png?odnHeight=180&amp;odnWidth=180&amp;odnBg=FFFFFF 2x" width="90"/><p class="tc f6 dark-gray ma0 mv2">Custom Cakes</p></a></div></div></div></section></div></div></div><div class="w_AC w_BB w_AG"><div class="flex flex-column h-100" data-testid="flex-container"><div class="h-100 relative"><div class="mv3 mt3-l mb0-l mt4-xl mh3 mh0-l"><div class="w_DR w_DU pb0" style="width:auto;height:395px"><div class="w_DT"><h2 class="f4 f3-m b dark-gray truncate ma0 lh-copy" style="height:28px">Tech deals</h2><div class="flex flex-column justify-center relative"><ul class="list ma0 pl0 overflow-x-scroll hidesb hidesb-wk relative overflow-y-hidden carousel-1" data-testid="carousel-container" style="display:grid;grid-auto-flow:column;scroll-snap-type:x mandatory;max-height:fit-content"><li class="flex flex-column items-center" data-slide="0"><div class="ma0 justify-between content-between pt4" style="padding-left:24px;padding-right:24px"><div class="w_c w_d"><div class="w_AC w_BB w_AI"><div class="tc" style="margin-bottom:40px"><a aria-
link-identifier="itemClick"><img alt="" class="h-auto" height="112" loading="lazy" src="https://i5.walmartimages.com/dfw/4ff9c6c9-31a2/k2-_e28b1ab9-3a6e-496c-a3de-c59822e7f8b5.v1.jpg?odnHeight=112&amp;odnWidth=112&amp;odnBg=FFFFFF" srcset="https://i5.walmartimages.com/dfw/4ff9c6c9-31a2/k2-_e28b1ab9-3a6e-496c-a3de-c59822e7f8b5.v1.jpg?odnHeight=112&amp;odnWidth=112&amp;odnBg=FFFFFF 1x," style="width:calc(100% - 3.5rem);max-width:112px" width="112"/><div class="w-100 tc mb3 mb0-m h3-xl mt1"><span class="ma0 mid-gray lh-copy f6 w_Q" style="-webkit-line-clamp:2;padding-bottom:0em;margin-bottom:-0em">Shop all</span></div></a></div><div class="w_AC w_BB w_AI tc"><a class="no-underline sans-serif" href="/shop/deals/electronics" link-identifier="itemClick"><img alt="" class="h-auto" height="112" loading="lazy" src="https://i5.walmartimages.com/dfw/4ff9c6c9-aaad/k2-_9fb5c5ab-688e-42c6-ba2d-5faa1de2c042.v1.jpg?odnHeight=112&amp;odnWidth=112&amp;odnBg=FFFFFF" srcset="https://i5.walmartimages.com/dfw/4ff9c6c9-aaad/k2-_9fb5c5ab-688e-42c6-ba2d-5faa1de2c042.v1.jpg?odnHeight=112&amp;odnWidth=112&amp;odnBg=FFFFFF 1x," style="width:calc(100% - 3.5rem);max-width:112px" width="112"/><div class="w-100 tc mb3 mb0-m h3-xl mt1"><span class="ma0 mid-gray lh-copy f6 w_Q" style="-webkit-line-clamp:2;padding-bottom:0em;margin-bottom:-0em">Electronics gifts</span></div></a></div><div class="w_AC w_BB w_AI tc"><a class="no-underline sans-serif" href="/shop/deals/toys" link-identifier="itemClick"><img alt="" class="h-auto" height="112" loading="lazy" src="https://i5.walmartimages.com/dfw/4ff9c6c9-6028/k2-_a5823939-2cb2-4e10-a323-c21f744b3841.v1.jpg?odnHeight=112&amp;odnWidth=112&amp;odnBg=FFFFFF" srcset="https://i5.walmartimages.com/dfw/4ff9c6c9-6028/k2-_a5823939-2cb2-4e10-a323-c21f744b3841.v1.jpg?odnHeight=112&amp;odnWidth=112&amp;odnBg=FFFFFF 1x," style="width:calc(100% - 3.5rem);max-width:112px" width="112"/><div class="w-100 tc mb3 mb0-m h3-xl mt1"><span class="ma0 mid-gray lh-copy f6 w_Q" style="-webkit-line-clamp:2;padding-bottom:0em;margin-bottom:-0em">Toy gifts</span></div></a></div><div class="w_AC w_BB w_AI tc"><a class="no-underline sans-serif" href="/shop/deals/all-home" link-identifier="itemClick"><img alt="" class="h-auto" height="112" loading="lazy" src="https://i5.walmartimages.com/dfw/4ff9c6c9-3bd7/k2-_ee9f0abd-7f2a-43a0-b412-690423db0963.v1.jpg?odnHeight=112&amp;odnWidth=112&amp;odnBg=FFFFFF" srcset="https://i5.walmartimages.com/dfw/4ff9c6c9-3bd7/k2-_ee9f0abd-7f2a-43a0-b412-690423db0963.v1.jpg?odnHeight=112&amp;odnWidth=112&amp;odnBg=FFFFFF 1x," style="width:calc(100% - 3.5rem);max-width:112px" width="112"/><div class="w-100 tc mb3 mb0-m h3-xl mt1"><span ...

# %%
soup.find_all("a", href=True)
# Out:
# [<a aria-label="Shop now" class="underline normal dark-gray ml2-m f6-m nowrap" href="/shop/deals" link-identifier="Shop now">Shop now</a>,
#  <a class="slider skip-main bg-white-90" href="#maincontent" link-identifier="Generic Name">Skip to Main Content</a>,
#  <a aria-label="Walmart Homepage" class="flex-none mr3" href="/" link-identifier="walmartLogo"><img alt="Walmart" class="db" height="32" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-b3e1/7a569e53-f29a-4c3d-bfaf-6f7a158bfadd/v1/walmartLogo.svg" width="130"/></a>,
#  <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline ph3 white desktop-header-trigger lh-title lh-solid" href="/my-items" link-identifier="Reorder my items" style="border-radius:100px;height:40px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)"><i aria-hidden="true" class="ld ld-Reorder" style="font-size:1rem;vertical-align:-0.175em"></i><div class="ml2 nowrap"><div class="f7 lh-title">Reorder</div><div class="b">My Items</div></div></a>,
#  <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" href="/my-items" link-identifier="Reorder"><i class="ld ld-Reorder mr2" style="font-size:1rem;vertical-align:-0.175em"></i>Reorder</a>,
#  <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" href="/lists" link-identifier="Lists"><i class="ld ld-List mr2" style="font-size:1rem;vertical-align:-0.175em"></i>Lists</a>,
#  <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" href="/my-registries" link-identifier="Registries"><i class="ld ld-Gift mr2" style="font-size:1rem;vertical-align:-0.175em"></i>Registries</a>,
#  <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline ph3 white desktop-header-trigger lh-title lh-solid" href="/account/login?vid=oaoh" link-identifier="Account" style="border-radius:100px;height:40px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)"><i aria-hidden="true" class="ld ld-User" style="font-size:1rem;vertical-align:-0.175em"></i><div class="ml2 nowrap"><div class="f7 mw3 mw4-xl lh-title truncate">Sign In</div><div class="b">Account</div></div></a>,
#  <a class="no-underline" href="/account/signup?vid=oaoh" link-identifier="Create an account"><button class="w_DE w_DH w_DK db mb3 w-100" tabindex="-1" type="button">Create an account</button></a>,
#  <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link" href="/orders" link-identifier="Purchase History"><i class="ld ld-Receipt mr2" style="font-size:1rem;vertical-align:-0.175em"></i>Purchase History</a>,
#  <a class="absolute absolute--fill no-underline" href="/shop/deals/up-to-40-percent-off-furniture-and-decor?athcpid=07e1e3cc-7a6c-4b7c-b96b-ab6af96a1f78&amp;athpgid=AthenaHomepageDesktop&amp;athznid=athenaModuleZone&amp;athmtid=AthenaHeroPov&amp;athtvid=2&amp;athena=true&amp;athstid=CS011%7CCS041&amp;athftid=P0000&amp;athguid=6Y4lfv6dwJ3Ayr1kJTqRm0_gJKaXMEt9e1eD" link-identifier="Shop now"><span class="w_CW">40% off select cozy home</span></a>,
#  <a class="w_DE w_DH w_DK mt3" href="/shop/deals/up-to-40-percent-off-furniture-and-decor?athcpid=07e1e3cc-7a6c-4b7c-b96b-ab6af96a1f78&amp;athpgid=AthenaHomepageDesktop&amp;athznid=athenaModuleZone&amp;athmtid=AthenaHeroPov&amp;athtvid=2&amp;athena=true&amp;athstid=CS011%7CCS041&amp;athftid=P0000&amp;athguid=6Y4lfv6dwJ3Ayr1kJTqRm0_gJKaXMEt9e1eD" style="color:#000000;background-color:#FFFFFF;box-shadow:inset 0 0 0 1px #000000">Shop now</a>,
#  <a class="absolute absolute--fill no-underline" href="/shop/gift-finder" link-identifier="Shop now"><span class="w_CW">Holiday gift finder</span></a>,
#  <a class="w_DE w_DH w_DK mt3" href="/shop/gift-finder" style="color:#000000;background-color:#FFFFFF;box-shadow:inset 0 0 0 1px #000000">Shop now</a>,
#  <a class="absolute absolute--fill no-underline" href="/cp/holiday-food/7998220" link-identifier="Shop all"><span class="w_CW">Holiday meal must-haves</span></a>,
#  <a class="w_DE w_DH w_DK mt3" href="/cp/holiday-food/7998220" style="color:#000000;background-color:#FFFFFF;box-shadow:inset 0 0 0 1px #000000">Shop all</a>,
#  <a class="absolute absolute--fill no-underline" href="/cp/toys/4171" link-identifier="Shop now"><span class="w_CW">Top toy gifts</span></a>,
#  <a class="w_DE w_DH w_DK mt3" href="/cp/toys/4171" style="color:#000000;background-color:#FFFFFF;box-shadow:inset 0 0 0 1px #000000">Shop now</a>,
#  <a class="absolute absolute--fill no-underline" href="/ip/Walmart-Annual-Membership-e-Gift-Card/870234932?povid=wpl_pov_gm&amp;athcpid=00f8e3d8-252f-4fdc-b514-f3b7a3c36ca7&amp;athpgid=AthenaHomepageDesktop&amp;athznid=athenaModuleZone&amp;athmtid=AthenaHeroPov&amp;athtvid=1&amp;athena=true&amp;athstid=CS100%7CCS041&amp;athguid=6Y4lfv6dwJ3Ayr1kJTqRm0_gJKaXMEt9e1eD&amp;athwpid=0" link-identifier="Give Walmart+"><span class="w_CW">The gift of Walmart+</span></a>,
#  <a class="w_DE w_DH w_DK mt3" href="/ip/Walmart-Annual-Membership-e-Gift-Card/870234932?povid=wpl_pov_gm&amp;athcpid=00f8e3d8-252f-4fdc-b514-f3b7a3c36ca7&amp;athpgid=AthenaHomepageDesktop&amp;athznid=athenaModuleZone&amp;athmtid=AthenaHeroPov&amp;athtvid=1&amp;athena=true&amp;athstid=CS100%7CCS041&amp;athguid=6Y4lfv6dwJ3Ayr1kJTqRm0_gJKaXMEt9e1eD&amp;athwpid=0" style="color:#000000;background-color:#FFFFFF;box-shadow:inset 0 0 0 1px #000000">Give Walmart+</a>,
#  <a class="f6 black" href="https://www.walmart.com/services" link-identifier="View All">View All</a>,
#  <a class="no-underline flex flex-column items-center ph2" href="https://www.walmart.com/cp/5431?gbo=1" link-identifier="Pharmacy"><img alt="" class="h-100" height="90" loading="lazy" src="https://i5.walmartimages.com/dfw/4ff9c6c9
#  <a aria-label="Weekly Ad - opens in a new window" class="no-underline pointer f6 white mr4" href="https://www.walmart.com/weeklyads" link-identifier="Weekly Ad" rel="noopener noreferrer" target="_blank">Weekly Ad</a>,
#  <a aria-label="Careers - opens in a new window" class="no-underline pointer f6 white mr4" href="https://careers.walmart.com/" link-identifier="Careers" rel="noopener noreferrer" target="_blank">Careers</a>,
#  <a aria-label="Our Company - opens in a new window" class="no-underline pointer f6 white mr4" href="https://corporate.walmart.com/" link-identifier="Our Company" rel="noopener noreferrer" target="_blank">Our Company</a>,
#  <a aria-label="Sell on Walmart.com - opens in a new window" class="no-underline pointer f6 white mr4" href="https://marketplace.walmart.com/?utm_source=Walmart.com&amp;utm_medium=link&amp;utm_campaign=footer" link-identifier="Sell on Walmart.com" rel="noopener noreferrer" target="_blank">Sell on Walmart.com</a>,
#  <a class="no-underline pointer f6 white mr4" href="/help" link-identifier="Help">Help</a>,
#  <a class="no-underline pointer f6 white mr4" href="https://www.walmart.com/cp/flu-shots-immunizations/1228302" link-identifier="COVID-19 Vaccine Scheduler">COVID-19 Vaccine Scheduler</a>,
#  <a aria-label="Product Recalls - opens in a new window" class="no-underline pointer f6 white mr4" href="https://corporate.walmart.com/recalls" link-identifier="Product Recalls" rel="noopener noreferrer" target="_blank">Product Recalls</a>,
#  <a class="no-underline pointer f6 white mr4" href="https://walmart.onelink.me/UIev?pid=walmart.com&amp;af_web_dp=https%3A%2F%2Fwww.walmart.com%2Fcp%2Fwalmart-mobile-app%2F1087865&amp;c=Walmart.com%20Site%20Footer&amp;af_dp=walmart%3A%2F%2F" link-identifier="Get the Walmart App">Get the Walmart App</a>,
#  <a class="no-underline pointer f6 white mr4" href="/help/article/walmart-com-terms-of-use/3b75080af40340d6bbd596f116fae5a0" link-identifier="Terms of Use">Terms of Use</a>,
#  <a aria-label="Privacy &amp; Security - opens in a new window" class="no-underline pointer f6 white mr4" href="https://corporate.walmart.com/privacy-security" link-identifier="Privacy &amp; Security" rel="noopener noreferrer" target="_blank">Privacy &amp; Security</a>,
#  <a aria-label="CA Privacy Rights - opens in a new window" class="no-underline pointer f6 white mr4" href="https://corporate.walmart.com/privacy-security/california-privacy-rights" link-identifier="CA Privacy Rights" rel="noopener noreferrer" target="_blank">CA Privacy Rights</a>,
#  <a aria-label="Do Not Sell My Personal Information - opens in a new window" class="no-underline pointer f6 white mr4" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=sod" link-identifier="Do Not Sell My Personal Information" rel="noopener noreferrer" target="_blank">Do Not Sell My Personal Information</a>,
#  <a aria-label="Request My Personal Information - opens in a new window" class="no-underline pointer f6 white" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=access" link-identifier="Request My Personal Information" rel="noopener noreferrer" target="_blank">Request My Personal Information</a>]

# %%
def get_title_links_from_page(url): # function 3-find pages of titles from main page
    """
    This function gets the links of the jobs on the joblist page.

    Args:
        url (str): link to game page

    Returns:
        job_page_links (list): list of links to the webpages of the jobs
    """

    page_links = []
    soup = get_soup(url) # call function 1
    #print('good soup')
    #print(soup.prettify())
    for item in soup.find_all("a", href=True):
        if 'link-identifier=' in str(item) and 'absolute' in str(item):#find out the links in the main pages
            link = item['href']
            #print(link)
            page_links.append(head+link)
    return page_links

# %%
links = get_title_links_from_page(head)
links
# Out:
# ['https://www.walmart.com//shop/deals/up-to-40-percent-off-furniture-and-decor?athcpid=07e1e3cc-7a6c-4b7c-b96b-ab6af96a1f78&athpgid=AthenaHomepageDesktop&athznid=athenaModuleZone&athmtid=AthenaHeroPov&athtvid=2&athena=true&athstid=CS011%7CCS041&athftid=P0000&athguid=GwljEIvThta7D5AGEALCpyLE8mPeveNskpA2',
#  'https://www.walmart.com//shop/gift-finder',
#  'https://www.walmart.com//cp/holiday-food/7998220',
#  'https://www.walmart.com//cp/toys/4171',
#  'https://www.walmart.com//ip/Walmart-Annual-Membership-e-Gift-Card/870234932?povid=wpl_pov_gm&athcpid=00f8e3d8-252f-4fdc-b514-f3b7a3c36ca7&athpgid=AthenaHomepageDesktop&athznid=athenaModuleZone&athmtid=AthenaHeroPov&athtvid=1&athena=true&athstid=CS100%7CCS041&athguid=GwljEIvThta7D5AGEALCpyLE8mPeveNskpA2&athwpid=0']

# %%
def get_original_link(url): # function 6-get original link
    """
    Get the original link of the job description.

    Args:
        url (str): the link in Indeed database

    Returns:
        url (str): the original link to the job description
    """
    driver = webdriver.Chrome(chromedriver)
    driver.get(url)
    time.sleep(2)
    self.original_url = driver.current_url
    driver.quit()
    return original_url

# %%
get_original_link(head) #open the walmart page, it will give the following error when you close the page
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-d162d3533c15> in <module>
# ----> 1 get_original_link(head)
#
# <ipython-input-23-ca492ca48947> in get_original_link(url)
#      12     driver.get(url)
#      13     time.sleep(2)
# ---> 14     self.original_url = driver.current_url
#      15     driver.quit()
#      16     return original_url
#
# NameError: name 'self' is not defined

# %%
def get_timestamp(time_str):
    """
    Calculate the timestamp from the time string.

    Args:
        time_str (str): time string, like '2 hours ago'

    Returns:
        time_stamp (obj): timestamp object
    """
    if 'hour' in time_str:
        lag = int(time_str.split('hour')[0])
        delta = timedelta(hours=lag)
        now = datetime.utcnow().replace(second=0,minute=0)
        return now-delta
    else:
        return -1

# %%
get_timestamp('2 hours ago')
# Out:
# datetime.datetime(2021, 12, 9, 3, 0, 0, 278505)

# %%
def get_info_from_product_page(url): # function4-get info of each item of job
    """
    This function get all the useful info from the job webpage.

    Args:
        url (str): link to job webpage

    Returns:
        data (dict): dictionary with keywords: 
                     time_stamp, original_link, search_key, location, company, description
    """
    soup = get_soup(url)
    data = {}
    #time_str = soup.find('div',class_='result-link-bar').find('span').getText()
    #print('start:')
    try:
        data["time_stamp"] = self.get_timestamp(time_str).strftime("%d-%m-%Y %H:%M")
#             data["job_title"] = soup.find('b', class_='jobtitle').getText()
#             data["location"] = soup.find('span', class_='location').getText()
#             data["company"] = soup.find('span', class_='company').getText()
#             data["description"] = soup.find('td',class_='snip').find('div').getText()
        data["name"] = soup.find('h', itemprop='name').getText()
        data["price"] = soup.find('span', itemprop='price').getText()
        data['Rating'] = soup.find('span', itemprop='ratingCount').getText()
        
#         re_link = soup.find('a',class_='ratingCount')['href'].split("&from=")[0]
#         re_link = head[:-1]+re_link
#         data["original_link"] = self.get_original_link(re_link)
    except:
        pass
    return data

# %%
get_info_from_product_page("https://www.walmart.com/ip/LEGO-City-Wildlife-Rescue-Operation-60302-Building-Toy-for-Kids-525-Pieces/905209204")
# Out:
# {}

# %%
def get_products(title):
    """
    Args:
        job_title (str): example: 'data+scientist'

    Returns:
    """

    #needed to be changed
#     num_pages = 1 #number of pages to scrape
#     page_gap_min = 3 #min sleep time between pages
#     page_gap_max = 5 #max sleep time between pages
#     job_per_page = 50 #number of jobs in one page
    job_gap_min = 5 #min sleep time between jobs
    job_gap_max = 6 #max sleep time between jobs
    
    url = "https://www.walmart.com/search?q="
    title_list = title.split()
    links = []
    for i in range(len(title_list)):
        url+='+'
        url+=title_list[i]
    links = get_title_links_from_page(head)
    
    for link in links:
        gap = np.random.uniform(job_gap_min, job_gap_max)
        time.sleep(gap)
        data = get_info_from_product_page(link)
        print(json.dums(data))

#     for i in range(num_pages): 
#         #sleep between each call
#         gap = random.uniform(page_gap_min,page_gap_max) 
#         time.sleep(gap)

#         #each page contains 50 jobs
#         tail = "jobs?q={0}&sort=date&limit={1}".format(job_title,job_per_page)
#         if i>0:
#             tail += "&start={0}".format(i*job_per_page)

#         #get link to joblist page
#         url = head+tail 
         
#         #get links to webpages of jobs on the joblist
#         job_page_links = get_job_links_from_page(url)

#         for job_page_link in job_page_links:
#             gap = random.uniform(job_gap_min,job_gap_max) 
#             time.sleep(gap)
#             data = get_info_from_job_page(job_page_link)

#             print(json.dumps(data))

# %%
def get_jobs_of_title(title): # function2-find info of each items of job in all pages
    """
    Args:
        search_key (str): example: 'nintendo+switch+games'

    Returns:
    """
    head = 'https://www.walmart.com/'
    #needed to be changed
    num_pages = 2 #number of pages to scrape
    page_gap_min = 3 #min sleep time between pages
    page_gap_max = 5 #max sleep time between pages
    job_per_page = 40 #number of jobs in one page
    job_gap_min = 5 #min sleep time between jobs
    job_gap_max = 15 #max sleep time between jobs

    for i in range(num_pages): 
        #sleep between each call
        gap = random.uniform(page_gap_min,page_gap_max) 
        time.sleep(gap)

        #each page contains 50 jobs
        tail = ''
        if i == 0:
            tail = 'search?q={0}'.format(title)
        else:
            tail = 'search?q={0}&page={1}&affinityOverride=default'.format(title,i+1)

        #get link to joblist page
        url = head+tail 
        print(url)
        #get links to webpages of jobs on the joblist
        job_page_links = get_title_links_from_page(head) # call fuction 3
        #print(job_page_links)

        for job_page_link in job_page_links:
            gap = random.uniform(job_gap_min,job_gap_max) 
            time.sleep(gap)
            data_new = get_info_from_product_page(job_page_link) # call function 4
            #print(data_new)
            print(json.dumps(data_new))

# %%
get_jobs_of_title(title)
# Out:
# https://www.walmart.com/search?q=['kids+toys']
# {}
# {}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-80f97bde88d8> in <module>
# ----> 1 get_jobs_of_title(title)
#
# <ipython-input-49-0ef835059dce> in get_jobs_of_title(title)
#      36         for job_page_link in job_page_links:
#      37             gap = random.uniform(job_gap_min,job_gap_max)
# ---> 38             time.sleep(gap)
#      39             data_new = get_info_from_product_page(job_page_link) # call function 4
#      40             #print(data_new)
#
# KeyboardInterrupt:
